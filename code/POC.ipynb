# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import mean_squared_error
import numpy as np
from pathlib import Path
from pandas import DataFrame

# %%
def rmse(a, b):
    return np.sqrt(mean_squared_error(a, b))

# %%
def load_df(folder: Path) -> DataFrame:
    return pd.read_csv(folder/"data.csv")

# %%
def load_data_for_model(original_data: DataFrame) -> DataFrame:
    columns_to_drop = original_data.columns[original_data.columns.str.contains("_name")]
    original_data = original_data.drop(columns=columns_to_drop)
    X = original_data.drop(columns=["item_cnt_month"])
    y = original_data["item_cnt_month"]
    return X, y

# %%
train_folder = Path("../data/prepared/train/")
val_folder = Path("../data/prepared/val/")

# %%
train_df = load_df(train_folder)
val_df = load_df(val_folder)

# %%
X_train, y_train = load_data_for_model(train_df)
X_val, y_val = load_data_for_model(val_df)

# %%
X_train
# Out:
#          shop_id  item_id  date_block_num  date_year  date_month  item_price  \
# 0              0       32               1       2013           1       221.0
# 1              1       32               1       2013           1       221.0
# 2              3       32               1       2013           1       349.0
# 3              4       32               1       2013           1       349.0
# 4              5       32               1       2013           1       349.0
# ...          ...      ...             ...        ...         ...         ...
# 1730110       55    15073              33       2015           9       299.0
# 1730111       55    16801              33       2015           9       790.0
# 1730112       55    19444              33       2015           9       186.0
# 1730113       56    18483              33       2015           9       349.0
# 1730114       58    20267              33       2015           9       169.0
#
#          item_category_id
# 0                      40
# 1                      40
# 2                      40
# 3                      40
# 4                      40
# ...                   ...
# 1730110                31
# 1730111                78
# 1730112                31
# 1730113                57
# 1730114                40
#
# [1730115 rows x 7 columns]

# %%
X_val
# Out:
#        shop_id  item_id  date_block_num  date_year  date_month  item_price  \
# 0            2       31              34       2015          10      399.00
# 1            6       31              34       2015          10      324.00
# 2           18       31              34       2015          10      399.00
# 3           21       31              34       2015          10      391.48
# 4           22       31              34       2015          10      395.12
# ...        ...      ...             ...        ...         ...         ...
# 34051       59     5647              34       2015          10      998.00
# 34052       59     6563              34       2015          10      499.00
# 34053       59     9905              34       2015          10     1109.00
# 34054       59    14256              34       2015          10       99.00
# 34055       59    19708              34       2015          10      949.00
#
#        item_category_id
# 0                    37
# 1                    37
# 2                    37
# 3                    37
# 4                    37
# ...                 ...
# 34051                 2
# 34052                25
# 34053                37
# 34054                37
# 34055                41
#
# [34056 rows x 7 columns]

# %%
gb_reg = GradientBoostingRegressor(n_estimators=100)

# %%
gb_reg.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
prediction = gb_reg.predict(X_val).clip(0, 20)

# %%
prediction
# Out:
# array([1.17315575, 1.5106117 , 1.41374416, ..., 1.53671332, 1.13387436,
#        1.38539056])

# %%
X_val
# Out:
#        shop_id  item_id  date_block_num  date_year  date_month  item_price  \
# 0            2       31              34       2015          10      399.00
# 1            6       31              34       2015          10      324.00
# 2           18       31              34       2015          10      399.00
# 3           21       31              34       2015          10      391.48
# 4           22       31              34       2015          10      395.12
# ...        ...      ...             ...        ...         ...         ...
# 34051       59     5647              34       2015          10      998.00
# 34052       59     6563              34       2015          10      499.00
# 34053       59     9905              34       2015          10     1109.00
# 34054       59    14256              34       2015          10       99.00
# 34055       59    19708              34       2015          10      949.00
#
#        item_category_id
# 0                    37
# 1                    37
# 2                    37
# 3                    37
# 4                    37
# ...                 ...
# 34051                 2
# 34052                25
# 34053                37
# 34054                37
# 34055                41
#
# [34056 rows x 7 columns]

# %%
test_range = pd.read_csv("../data/src/test.csv", index_col=["shop_id", "item_id"])
target_df = test_range.join(val_df.set_index(["shop_id", "item_id"]).assign(prediction=prediction)).assign(
    date_block_num=(24 + 9), 
    item_cnt_month=lambda df: df.item_cnt_month.fillna(0),
    prediction=lambda df: df.prediction.fillna(0),
    date_year=2015, 
    date_month=9,
)

# %%
rmse(target_df.item_cnt_month, target_df.prediction)
# Out:
# 0.7123520541586794

# %%
target_df
# Out:
#                      ID  date_block_num  item_cnt_month  date_year  \
# shop_id item_id
# 5       5037          0              33             0.0       2015
#         5320          1              33             0.0       2015
#         5233          2              33             0.0       2015
#         5232          3              33             0.0       2015
#         5268          4              33             0.0       2015
# ...                 ...             ...             ...        ...
# 45      18454    214195              33             2.0       2015
#         16188    214196              33             0.0       2015
#         15757    214197              33             0.0       2015
#         19648    214198              33             0.0       2015
#         969      214199              33             0.0       2015
#
#                  date_month  item_price    item_name  item_category_id  \
# shop_id item_id
# 5       5037              9         NaN          NaN               NaN
#         5320              9         NaN          NaN               NaN
#         5233              9         NaN          NaN               NaN
#         5232              9         NaN          NaN               NaN
#         5268              9         NaN          NaN               NaN
# ...                     ...         ...          ...               ...
# 45      18454             9       149.0  СБ. Союз 55              55.0
#         16188             9         NaN          NaN               NaN
#         15757             9         NaN          NaN               NaN
#         19648             9         NaN          NaN               NaN
#         969               9         NaN          NaN               NaN
#
#                                   item_category_name  prediction
# shop_id item_id
# 5       5037                                     NaN     0.00000
#         5320                                     NaN     0.00000
#         5233                                     NaN     0.00000
#         5232                                     NaN     0.00000
#         5268                                     NaN     0.00000
# ...                                              ...         ...
# 45      18454    Музыка - CD локального производства     1.13876
#         16188                                    NaN     0.00000
#         15757                                    NaN     0.00000
#         19648                                    NaN     0.00000
#         969                                      NaN     0.00000
#
# [214200 rows x 10 columns]

# %%
target_df.reset_index(drop=True)[["ID", "item_cnt_month"]].to_csv("../submission.csv", index=False)
